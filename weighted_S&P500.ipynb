# %% [markdown]
# <a href="https://colab.research.google.com/github/ddavila9789/Equal-Weighted-SP-500/blob/main/weighted_S%26P500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader

# %%
import numpy as np #The Numpy numerical computing library
import pandas as pd #The Pandas data science library
import requests #The requests library for HTTP requests in Python
import math #The Python math module
import datetime as dt
import pandas_datareader as web
import fix_yahoo_finance as yf
import requests
from bs4 import BeautifulSoup
from datetime import date

# %%
#web scraping all symbols in the S&P 500
URL = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find("table", {'id':"constituents"})
df=pd.read_html(str(results))
# convert list to dataframe
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %%
stocks = df.sort_values(by=['Symbol']).reset_index(drop=True)
stocks['Symbol'] = df['Symbol'].str.replace('.','-')
stocks = stocks[['Symbol']]
stocks
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#     Symbol
# 0      MMM
# 1      AOS
# 2      ABT
# 3     ABBV
# 4     ABMD
# ..     ...
# 499    YUM
# 500   ZBRA
# 501    ZBH
# 502   ZION
# 503    ZTS
#
# [504 rows x 1 columns]

# %%
next = stocks.tail(-363)
next.reset_index(drop=True)
# Out:
#     Symbol
# 0       PH
# 1     PAYX
# 2     PAYC
# 3     PYPL
# 4     PENN
# ..     ...
# 136    YUM
# 137   ZBRA
# 138    ZBH
# 139   ZION
# 140    ZTS
#
# [141 rows x 1 columns]

# %%
my_columns = ['Symbol', 'Price','Market_Capitalization', 'Number Of Shares to Buy']
final_dataframe = pd.DataFrame(columns = my_columns)
next_dataframe = pd.DataFrame(columns = my_columns)
final_dataframe
# Out:
# Empty DataFrame
# Columns: [Symbol, Price, Market_Capitalization, Number Of Shares to Buy]
# Index: []

# %%
next_dataframe = pd.DataFrame(columns = my_columns)

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
symbol_groups = list(chunks(next['Symbol'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
#     print(symbol_strings[i])

next_dataframe = pd.DataFrame(columns = my_columns)

for symbol_string in symbol_strings:
#     print(symbol_strings)
    for symbol in symbol_string.split(','):
        data = web.get_quote_yahoo(symbol)
        next_dataframe = next_dataframe.append(
                                        pd.Series([symbol, 
                                                   data['price'], 
                                                   data['marketCap'],
                                                   'N/A'], 
                                                  index = my_columns), 
                                        ignore_index = True)
        
    
next_dataframe
# Out:
#     Symbol                                       Price  \
# 0       PH    PH    276.84
# Name: price, dtype: float64
# 1     PAYX  PAYX    125.81
# Name: price, dtype: float64
# 2     PAYC  PAYC    298.52
# Name: price, dtype: float64
# 3     PYPL   PYPL    86.53
# Name: price, dtype: float64
# 4     PENN   PENN    32.91
# Name: price, dtype: float64
# ..     ...                                         ...
# 136    YUM   YUM    118.62
# Name: price, dtype: float64
# 137   ZBRA  ZBRA    334.77
# Name: price, dtype: float64
# 138    ZBH   ZBH    120.63
# Name: price, dtype: float64
# 139   ZION   ZION    56.54
# Name: price, dtype: float64
# 140    ZTS   ZTS    169.01
# Name: price, dtype: float64
#
#                                  Market_Capitalization Number Of Shares to Buy
# 0      PH    35538505728
# Name: marketCap, dtype: int64                     N/A
# 1    PAYX    45419548672
# Name: marketCap, dtype: int64                     N/A
# 2    PAYC    19320541184
# ...

# %%
symbol_groups = list(chunks(stocks['Symbol'], 100))
symbol_strings = []
for i in range(0, len(symbol_groups)):
    symbol_strings.append(','.join(symbol_groups[i]))
#     print(symbol_strings[i])

final_dataframe = pd.DataFrame(columns = my_columns)

for symbol_string in symbol_strings:
#     print(symbol_strings)
    for symbol in symbol_string.split(','):
        data = web.get_quote_yahoo(symbol)
        final_dataframe = final_dataframe.append(
                                        pd.Series([symbol, 
                                                   data['price'], 
                                                   data['marketCap'], 
                                                   'N/A'], 
                                                  index = my_columns), 
                                        ignore_index = True)
        
final_dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marketCap'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
final_dataframe
# Out:
#     Symbol                                       Price  \
# 0      MMM   MMM    145.97
# Name: price, dtype: float64
# 1      AOS    AOS    60.84
# Name: price, dtype: float64
# 2      ABT   ABT    116.57
# Name: price, dtype: float64
# 3     ABBV  ABBV    147.17
# Name: price, dtype: float64
# 4     ABMD  ABMD    262.25
# Name: price, dtype: float64
# ..     ...                                         ...
# 357   ORCL   ORCL    71.79
# Name: price, dtype: float64
# 358    OGN    OGN    37.18
# Name: price, dtype: float64
# 359   OTIS   OTIS    75.19
# Name: price, dtype: float64
# 360   PCAR   PCAR    88.29
# Name: price, dtype: float64
# 361    PKG   PKG    159.12
# Name: price, dtype: float64
#
#                                  Market_Capitalization Number Of Shares to Buy
# 0     MMM    83065544704
# Name: marketCap, dtype: int64                     N/A
# 1      AOS    9604506624
# Name: marketCap, dtype: int64                     N/A
# 2    ABT    204107071488
# ...

# %%
next_dataframe
# Out:
#     Symbol                                       Price  \
# 0       PH    PH    276.84
# Name: price, dtype: float64
# 1     PAYX  PAYX    125.81
# Name: price, dtype: float64
# 2     PAYC  PAYC    298.52
# Name: price, dtype: float64
# 3     PYPL   PYPL    86.53
# Name: price, dtype: float64
# 4     PENN   PENN    32.91
# Name: price, dtype: float64
# ..     ...                                         ...
# 136    YUM   YUM    118.62
# Name: price, dtype: float64
# 137   ZBRA  ZBRA    334.77
# Name: price, dtype: float64
# 138    ZBH   ZBH    120.63
# Name: price, dtype: float64
# 139   ZION   ZION    56.54
# Name: price, dtype: float64
# 140    ZTS   ZTS    169.01
# Name: price, dtype: float64
#
#                                  Market_Capitalization Number Of Shares to Buy
# 0      PH    35538505728
# Name: marketCap, dtype: int64                     N/A
# 1    PAYX    45419548672
# Name: marketCap, dtype: int64                     N/A
# 2    PAYC    19320541184
# ...

# %%
frames = [final_dataframe, next_dataframe]
result = pd.concat(frames)
result = result.reset_index(drop=True)
b_result = result
result
# Out:
#     Symbol                                       Price  \
# 0      MMM   MMM    145.97
# Name: price, dtype: float64
# 1      AOS    AOS    60.84
# Name: price, dtype: float64
# 2      ABT   ABT    116.57
# Name: price, dtype: float64
# 3     ABBV  ABBV    147.17
# Name: price, dtype: float64
# 4     ABMD  ABMD    262.25
# Name: price, dtype: float64
# ..     ...                                         ...
# 498    YUM   YUM    118.62
# Name: price, dtype: float64
# 499   ZBRA  ZBRA    334.77
# Name: price, dtype: float64
# 500    ZBH   ZBH    120.63
# Name: price, dtype: float64
# 501   ZION   ZION    56.54
# Name: price, dtype: float64
# 502    ZTS   ZTS    169.01
# Name: price, dtype: float64
#
#                                  Market_Capitalization Number Of Shares to Buy
# 0     MMM    83065544704
# Name: marketCap, dtype: int64                     N/A
# 1      AOS    9604506624
# Name: marketCap, dtype: int64                     N/A
# 2    ABT    204107071488
# ...

# %%
list = [['PARA', web.get_quote_yahoo('PARA')['price'], web.get_quote_yahoo('PARA')['marketCap'],'N/A']]

result = result.append(pd.DataFrame(list,
               columns= my_columns),
               ignore_index = True)
result
# Out:
#     Symbol                                       Price  \
# 0      MMM   MMM    145.97
# Name: price, dtype: float64
# 1      AOS    AOS    60.84
# Name: price, dtype: float64
# 2      ABT   ABT    116.57
# Name: price, dtype: float64
# 3     ABBV  ABBV    147.17
# Name: price, dtype: float64
# 4     ABMD  ABMD    262.25
# Name: price, dtype: float64
# ..     ...                                         ...
# 499   ZBRA  ZBRA    334.77
# Name: price, dtype: float64
# 500    ZBH   ZBH    120.63
# Name: price, dtype: float64
# 501   ZION   ZION    56.54
# Name: price, dtype: float64
# 502    ZTS   ZTS    169.01
# Name: price, dtype: float64
# 503   PARA    PARA    30.8
# Name: price, dtype: float64
#
#                                  Market_Capitalization Number Of Shares to Buy
# 0     MMM    83065544704
# Name: marketCap, dtype: int64                     N/A
# 1      AOS    9604506624
# Name: marketCap, dtype: int64                     N/A
# 2    ABT    204107071488
# ...

# %%
result['Price'] = result['Price'].astype(float)
result["Market_Capitalization"] = result["Market_Capitalization"].astype(int)
b_result = result
result
# Out:
#     Symbol   Price  Market_Capitalization Number Of Shares to Buy
# 0      MMM  145.97            83065544704                     N/A
# 1      AOS   60.84             9604506624                     N/A
# 2      ABT  116.57           204107071488                     N/A
# 3     ABBV  147.17           260065574912                     N/A
# 4     ABMD  262.25            11949132800                     N/A
# ..     ...     ...                    ...                     ...
# 499   ZBRA  334.77            17580044288                     N/A
# 500    ZBH  120.63            25281271808                     N/A
# 501   ZION   56.54             8557838336                     N/A
# 502    ZTS  169.01            79541002240                     N/A
# 503   PARA   30.80            20082462720                     N/A
#
# [504 rows x 4 columns]

# %%
portfolio_size = input("Enter the value of your portfolio:")

try:
    val = float(portfolio_size)
except ValueError:
    print("That's not a number! \n Try again:")
    portfolio_size = input("Enter the value of your portfolio:")
# Out:
# Enter the value of your portfolio:10000000

# %%
position_size = float(portfolio_size) / len(result.index)
for i in range(0, len(result['Symbol'])-1):
    result.loc[i, 'Number Of Shares to Buy'] = math.floor(position_size / result['Price'][i])
result
# Out:
#     Symbol   Price  Market_Capitalization Number Of Shares to Buy
# 0      MMM  145.97            83065544704                     135
# 1      AOS   60.84             9604506624                     326
# 2      ABT  116.57           204107071488                     170
# 3     ABBV  147.17           260065574912                     134
# 4     ABMD  262.25            11949132800                      75
# ..     ...     ...                    ...                     ...
# 499   ZBRA  334.77            17580044288                      59
# 500    ZBH  120.63            25281271808                     164
# 501   ZION   56.54             8557838336                     350
# 502    ZTS  169.01            79541002240                     117
# 503   PARA   30.80            20082462720                       6
#
# [504 rows x 4 columns]

# %%
result.to_excel("Equal_Weighted_S&P_500.xlsx")
